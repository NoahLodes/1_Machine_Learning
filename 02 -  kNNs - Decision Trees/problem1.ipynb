# %%
import matplotlib.pyplot as plt
import math

# %%
# Data
x1 = [1.0, 2.0, 1.0, 3.0, 5.5, 5.5]
x2 = [1.0, 0.5, 2.5, 3.5, 3.5, 2.5]
classes = [1, 1, 1, 2, 2, 2]

# Create a scatter plot
plt.scatter(x1, x2, c=classes, cmap=plt.cm.Paired, s=100, marker='o')

plt.show()

# %%
def Eucledian_distance(x1,x2):

    nearest_neighbor = []

    for x_1, x_2 in zip(x1,x2):
        distance_neighbors = []
        distance = 0
        sum = 0
        for x_i, x_j in zip(x1, x2):
            sum = (x_1-x_i)**2 + (x_2-x_j)**2
            distance = math.sqrt(sum)
            distance_neighbors.append(distance)
            distance_neighbors = [i for i in distance_neighbors if i != 0]
            
    nearest_neighbor.append(min(distance_neighbors))
    return nearest_neighbor

# %%
Eucledian_distance(x1,x2)
# Out:
# [1.0]
