# %%
import numpy as np
import matplotlib.pyplot as plt

from scipy.special import loggamma
# %matplotlib inline

# %%
x = np.linspace(1e-5, 1-1e-5, 1000)
tails_proba = 0.6
num_samples = 20
samples = np.random.choice([0, 1], size=(num_samples), p=[1 - tails_proba, tails_proba])
num_ones = np.count_nonzero(samples == 1)
num_zeros = np.count_nonzero(samples == 0)
theta = 0.7
p = x**num_ones*((1-x)**num_zeros)
print()

# %%
a, b = 3, 5
x = np.linspace(1e-5, 1-1e-5, 1000)

log_prior = (loggamma(a+b)/(loggamma(a)*loggamma(b)))*theta**(a-1)*(1-theta)**(b-1)

# %%
a, b = 3, 5
np.exp((loggamma(a+b)/(loggamma(a)*loggamma(b)))*x**(a-1)*(1-x)**(b-1))
# Out:
# array([1.        , 1.00000394, 1.00001554, 1.00003471, 1.00006136,
#        1.0000954 , 1.00013673, 1.00018527, 1.00024093, 1.00030363,
#        1.00037327, 1.00044977, 1.00053304, 1.000623  , 1.00071956,
#        1.00082264, 1.00093215, 1.00104802, 1.00117016, 1.00129849,
#        1.00143293, 1.00157339, 1.00171981, 1.00187209, 1.00203017,
#        1.00219395, 1.00236338, 1.00253836, 1.00271883, 1.0029047 ,
#        1.0030959 , 1.00329236, 1.003494  , 1.00370076, 1.00391254,
#        1.0041293 , 1.00435094, 1.0045774 , 1.00480862, 1.00504451,
#        1.005285  , 1.00553004, 1.00577955, 1.00603346, 1.0062917 ,
#        1.0065542 , 1.0068209 , 1.00709174, 1.00736664, 1.00764553,
#        1.00792836, 1.00821506, 1.00850556, 1.00879981, 1.00909772,
#        1.00939925, 1.00970434, 1.0100129 , 1.0103249 , 1.01064026,
#        1.01095892, 1.01128082, 1.01160591, 1.01193412, 1.01226539,
#        1.01259966, 1.01293688, 1.01327699, 1.01361992, 1.01396562,
# ...
